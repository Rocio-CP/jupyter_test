# %%
from erddapy import ERDDAP
from erddapy.doc_helpers import show_iframe

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import cartopy
cartopy.config['data_dir'] = './maps'
import cartopy.crs as ccrs
from cartopy.feature import NaturalEarthFeature
import cartopy.feature as feat

# %% [markdown]
# # List available servers

# %%
from erddapy import servers
{k: [v.url,v.description] for k, v in servers.items()} # dictionary version
# Out:
# {'CSWC': ['https://coastwatch.pfeg.noaa.gov/erddap/',
#   'CoastWatch West Coast Node'],
#  'APDRC': ['https://apdrc.soest.hawaii.edu/erddap/',
#   'ERDDAP at the Asia-Pacific Data-Research Center'],
#  'NCEI': ['https://www.ncei.noaa.gov/erddap/',
#   "NOAA's National Centers for Environmental Information (NCEI)"],
#  'BCODMO': ['https://erddap.bco-dmo.org/erddap/',
#   'Biological and Chemical Oceanography Data Management Office (BCO-DMO) ERDDAP'],
#  'EMODnet': ['https://erddap.emodnet-physics.eu/erddap/',
#   'European Marine Observation and Data Network (EMODnet) Physics ERDDAP'],
#  'MII': ['https://erddap.marine.ie/erddap/', 'Marine Institute - Ireland'],
#  'CSCGOM': ['https://cwcgom.aoml.noaa.gov/erddap/',
#   'CoastWatch Caribbean/Gulf of Mexico Node'],
#  'IOOS-Sensors': ['https://erddap.sensors.ioos.us/erddap/',
#   'NOAA IOOS Sensors ERDDAP'],
#  'CeNCOOS': ['https://erddap.axiomdatascience.com/erddap/',
#   'NOAA IOOS CeNCOOS (Central and Northern California Ocean Observing System)'],
#  'NERACOOS': ['http://www.neracoos.org/erddap/',
#   'NOAA IOOS NERACOOS (Northeastern Regional Association of Coastal and Ocean Observing Systems)'],
#  'NGDAC': ['https://gliders.ioos.us/erddap/',
#   'NOAA IOOS NGDAC (National Glider Data Assembly Center)'],
#  'PacIOOS': ['https://pae-paha.pacioos.hawaii.edu/erddap/',
#   'NOAA IOOS PacIOOS (Pacific Islands Ocean Observing System) at the University of Hawaii (UH)'],
#  'SCCOOS': ['https://sccoos.org/erddap/',
#   'Southern California Coastal Ocean Observing System (SCCOOS)'],
#  'SECOORA': ['http://erddap.secoora.org/erddap/',
#   'NOAA IOOS SECOORA (Southeast Coastal Ocean Observing Regional Association)'],
#  'OSMC': ['http://osmc.noaa.gov/erddap/',
#   'NOAA OSMC (Observing System Monitoring Center)'],
#  'ONC': ['http://dap.onc.uvic.ca/erddap/', 'ONC (Ocean Networks Canada)'],
#  'PIFSC': ['https://oceanwatch.pifsc.noaa.gov/erddap/', ''],
#  'OOI Uncabled': ['https://erddap-uncabled.oceanobservatories.org/uncabled/erddap/',
#   'Ocean Observatories Initiative (OOI) Uncabled'],
#  'OOI Goldcopy': ['https://erddap-goldcopy.dataexplorer.oceanobservatories.org/erddap/',
#   'Ocean Observatories Initiative (OOI) Goldcopy'],
#  'OTN': ['https://members.oceantrack.org/erddap/', 'Ocean Tracking Network'],
#  'MYROMS': ['http://www.myroms.org:8080/erddap/',
#   'Regional Ocean Modelling System'],
#  'RUTGERS': ['http://tds.marine.rutgers.edu/erddap/',
#   'Department of Marine and Coastal Sciences, School of Environmental and Biological Sciences, Rutgers, The State University of New Jersey'],
#  'NEFSC': ['https://comet.nefsc.noaa.gov/erddap/', ''],
#  'COOPS-NOS': ['https://opendap.co-ops.nos.noaa.gov/erddap/',
#   "NOAA's Center for Operational Oceanographic Products and Services"],
#  'GCOO5-TAMU': ['https://gcoos5.geos.tamu.edu/erddap/',
#   'GCOOS Atmospheric and Oceanographic: Historical Data'],
#  'GCOO4-TAMU': ['https://gcoos4.tamu.edu/erddap/',
#   'GCOOS Biological and Socioeconomics'],
#  'GLERL': ['https://coastwatch.glerl.noaa.gov/erddap/',
#   'NOAA CoastWatch Great Lakes Node'],
#  'UCSD': ['https://spraydata.ucsd.edu/erddap/',
#   'Spray Underwater Glider data from Instrument Development Group, Scripps Institute of Oceanography, University of California, San Diego'],
#  'UBC': ['https://salishsea.eos.ubc.ca/erddap/',
#   'UBC Earth, Ocean & Atmospheric Sciences SalishSeaCast Project'],
#  'BMLSC': ['http://bmlsc.ucdavis.edu:8080/erddap/',
#   'UC Davis BML (University of California at Davis, Bodega Marine Laboratory)'],
#  'UAF': ['https://upwell.pfeg.noaa.gov/erddap/',
#   'NOAA UAF (Unified Access Framework)'],
#  'MDA': ['https://bluehub.jrc.ec.europa.eu/erddap/',
#   'Marine Domain Awareness (MDA) - Italy'],
#  'RTECH': ['https://meteo.rtech.fr/erddap/', 'R.Tech Engineering'],
#  'IFREMER': ['https://www.ifremer.fr/erddap/',
#   'French Research Institute for the Exploitation of the Sea'],
#  'PMEL': ['https://ferret.pmel.noaa.gov/pmel/erddap',
#   'NOAA PMEL (Pacific Marine Environmental Laboratory)'],
#  'ALAMO': ['https://ferret.pmel.noaa.gov/alamo/erddap/',
#   'ALAMO (Air Launched Autonomous Micro-Observer)'],
#  'SOCAT': ['https://ferret.pmel.noaa.gov/socat/erddap/',
#   'SOCAT (Surface Ocean CO2 ATlas)'],
#  'HAKAI': ['https://catalogue.hakai.org/erddap/', 'HAKAI Institute'],
#  'NANOOS': ['https://wilson.coas.oregonstate.edu/erddap/',
#   'NANOOS (Northwest Association of Networked Ocean Observing Systems)'],
#  'POLARWATCH': ['https://polarwatch.noaa.gov/erddap/', 'NOAH Polar Watch'],
#  'NCI': ['http://nrm-erddap.nci.org.au/erddap/',
#   'NCI (National Computational Infrastructure'],
#  'USGS': ['https://geoport.usgs.esipfed.org/erddap/',
#   'USGS Coastal and Marine Geology Program'],
#  'INCOIS': ['https://erddap.incois.gov.in/erddap/',
#   'ESSO INCOIS (Indian National Centre for Ocean Information Services)'],
#  'ICHEC': ['https://erddap.ichec.ie/erddap/',
#   'ICHEC (Irish Centre for High-End Computing'],
#  'SmartAtlantic': ['https://www.smartatlantic.ca/erddap/', 'Smart Atlantic'],
#  'GRIIDC': ['https://erddap.griidc.org/erddap/',
#   'GRIIDC (Gulf of Mexico Research Initiative'],
#  'ATN-IOOS': ['https://atn.ioos.us/erddap/',
#   'NOAH ATN IOOS (Animal Telemetry Network)'],
#  'DIVER': ['https://pub-data.diver.orr.noaa.gov/erddap/',
#   'DIVER (NOAA Office of Response and Restoration)'],
#  'JEOPP': ['https://jeodpp.jrc.ec.europa.eu/services/erddap/',
#   'JEODPP ERDDAP server'],
#  'GCOOS': ['https://erddap.gcoos.org/erddap/',
#   'GCOOS Atmospheric and Oceanographic: Observing System'],
#  'CEOE': ['https://basin.ceoe.udel.edu/erddap/',
#   'University of Delaware, College of Earth, Ocean and Environment'],
#  'CIOOS Atlantic': ['https://cioosatlantic.ca/erddap/',
#   'Canadian Integrated Ocean Observatory System'],
#  'EMSO ERIC': ['http://erddap.emso.eu:8080/erddap/',
#   'European Multidisciplinary Seafloor and water column Observatory (EMSO)'],
#  'SO-CHIC': ['http://erddap.sochic-h2020.eu/erddap/',
#   'Southern Ocean Carbon and Heat Imact on Climate (SO-CHIC)'],
#  'NCCO': ['https://coastwatch.noaa.gov/erddap/',
#   'NOAA CoastWatch Central Operations'],
#  'CanWIN': ['https://canwinerddap.ad.umanitoba.ca/erddap/index.html',
#   'The Canadian Watershed Information Network at the University of Manitoba']}

# %% [markdown]
# # List datasets in server EMODnet

# %%
eall = ERDDAP(server="EMODnet")
print(eall.get_search_url(search_for="all",response="html"))
show_iframe(eall.get_search_url(search_for="all",response="html"))
print()
datasetid = eall.get_search_url(search_for="all",response="csv")
df = pd.read_csv(datasetid)
print(
    f'EMODnet has {len(set(df["tabledap"].dropna()))} '
    f'tabledap, {len(set(df["griddap"].dropna()))} '
    f'griddap, and {len(set(df["wms"].dropna()))} wms endpoints.'
)
print(df.columns)
print(df[["Dataset ID","Title"]])
# Out:
# https://erddap.emodnet-physics.eu/erddap/search/advanced.html?page=1&itemsPerPage=1000&protocol=(ANY)&cdm_data_type=(ANY)&institution=(ANY)&ioos_category=(ANY)&keywords=(ANY)&long_name=(ANY)&standard_name=(ANY)&variableName=(ANY)&minLon=(ANY)&maxLon=(ANY)&minLat=(ANY)&maxLat=(ANY)&searchFor=all
#
# EMODnet has 269 tabledap, 57 griddap, and 33 wms endpoints.
# Index(['griddap', 'Subset', 'tabledap', 'Make A Graph', 'wms', 'files',
#        'Accessible', 'Title', 'Summary', 'FGDC', 'ISO 19115', 'Info',
#        'Background Info', 'RSS', 'Email', 'Institution', 'Dataset ID'],
#       dtype='object')
#                                Dataset ID  \
# 0                             allDatasets
# 1                      BDC_Summary_FV_NRT
# 2               EP_ERD_SOO_BIOA_NN_NN_J18
# 3                           BDC_Binned_FV
# 4                          ZENODO_3250980
# ..                                    ...
# 322  OBSEA_SPLs_NAXYS_hydrophone_at_OBSEA
# 323              TAD_Tsunami_Alert_Device
# 324               UHSLC_global_daily_fast
# 325              UHSLC_global_hourly_fast
# 326         OBSEA_Pictures_649f_9d4e_b3b6
#
#                                                  Title
# 0    * The List of All Active Datasets in this ERDD...
# 1    A summary of oceanographic data from fishing v...
# 2    ASPeCt-Bio: Chlorophyll a in Antarctic sea ice...
# 3    Binned oceanographic data from fishing vessels...
# 4    Dissolved seawater chromium (Cr) concentration...
# ..                                                 ...
# 322                                SPL values at OBSEA
# 323                         TAD - Tsunami Alert Device
# 324        UHSLC Fast Delivery Tide Gauge Data (daily)
# 325       UHSLC Fast Delivery Tide Gauge Data (hourly)
# 326                         Underwater Camera at OBSEA
#
# [327 rows x 2 columns]

# %% [markdown]
# # Refining search: surface temperature from North Atlantic in 2016

# %%
# Constraints
datemin="2018-01-01T00:00:00Z"
datemax="2019-12-31T23:59:59Z"
latmin=15.0
latmax=60.
lonmin=-60.
lonmax=-10.
varstandname="sea_water_ph_reported_on_total_scale"
#varname="phph"

servconst = {
    "standard_name": varstandname,
    "min_lon": lonmin,
    "max_lon": lonmax,
    "min_lat": latmin,
    "max_lat": latmax,
    "min_time": datemin,
    "max_time": datemax,
    #"cdm_data_type": "trajectoryprofile"
}

# %% [markdown]
# ## List datasets

# %%
e = ERDDAP(server="EMODnet", protocol='tabledap')
show_iframe(e.get_search_url(response="html", **servconst))
# Out:
#         <iframe
#             width="100%"
#             height="950"
#             src="https://erddap.emodnet-physics.eu/erddap/search/advanced.html?page=1&itemsPerPage=1000&protocol=tabledap&cdm_data_type=(ANY)&institution=(ANY)&ioos_category=(ANY)&keywords=(ANY)&long_name=(ANY)&standard_name=sea_water_ph_reported_on_total_scale&variableName=(ANY)&minLon=-60.0&maxLon=-10.0&minLat=15.0&maxLat=60.0&minTime=1514764800.0&maxTime=1577836799.0"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
search_url = e.get_search_url(response="csv", **servconst)
search = pd.read_csv(search_url)
print(search.columns)
print(search[["Title","Dataset ID"]].values)
# Out:
# Index(['griddap', 'Subset', 'tabledap', 'Make A Graph', 'wms', 'files',
#        'Accessible', 'Title', 'Summary', 'FGDC', 'ISO 19115', 'Info',
#        'Background Info', 'RSS', 'Email', 'Institution', 'Dataset ID'],
#       dtype='object')
# [['EMODnet Physics - Collection of Ph (PHPH) Profiles -  MultiPointProfileObservation'
#   'EP_ERD_INT_PHPH_AL_PR_NRT']
#  ['EMODnet Physics - Collection of Ph (PHPH) TimeSeries -  MultiPointTimeSeriesObservation'
#   'EP_ERD_INT_PHPH_AL_TS_NRT']]

# %% [markdown]
# ## List variables of dataset

# %%
#e.dataset_id="EP_ERD_INT_PHPH_AL_TS_NRT"
e.dataset_id="EP_ERD_INT_PHPH_AL_PR_NRT"

# List of variables
info_url = e.get_info_url(response='csv')
info = pd.read_csv(info_url)
print(info.head(100))
print()
print(" ".join(info.loc[info["Row Type"] == "variable","Variable Name"]))
# Out:
#      Row Type Variable Name         Attribute Name Data Type  \
# 0   attribute     NC_GLOBAL          cdm_data_type    String
# 1   attribute     NC_GLOBAL  cdm_profile_variables    String
# 2   attribute     NC_GLOBAL               citation    String
# 3   attribute     NC_GLOBAL                comment    String
# 4   attribute     NC_GLOBAL                contact    String
# ..        ...           ...                    ...       ...
# 95  attribute         depth             _FillValue     float
# 96  attribute         depth           actual_range     float
# 97  attribute         depth                   axis    String
# 98  attribute         depth          ioos_category    String
# 99  attribute         depth              long_name    String
#
#                                                 Value
# 0                                             Profile
# 1                                 time,EP_PLATFORM_ID
# 2   Data are the property of the producer/owner di...
# 3   When missing DEPTH and PRES values are calcula...
# 4                         contacts@emodnet-physics.eu
# ..                                                ...
# 95                                         9.96921E36
# 96                                   -1.6, 9.96921E36
# 97                                                  Z
# 98                                           Location
# 99                                              Depth
#
# [100 rows x 5 columns]
#
# EP_PLATFORM_ID EP_PLATFORM_TYPE EP_PLATFORM_CODE EP_PLATFORM_LINK time TIME_QC depth DEPTH_QC pres PRES_QC latitude longitude POSITION_QC DIRECTION PHPH PHPH_QC PHPH_DM site_code platform_code platform_name pi_name area author source contributor_name contributor_url data_assembly_center institution_edmo_code institution_references institution wmo_platform_code

# %%
e.constraints= {
    "latitude<=": latmax,
    "latitude>=": latmin,
    "longitude>=": lonmin,
    "longitude<=": lonmax,
    "time>=": datemin,
    "time<=": datemax,
    "depth<=":10.,
#    "institution_edmo_code":
}
e.variables= ['time','latitude','longitude','depth', 'PHPH']

#dtype=object
df_emodnet = e.to_pandas()
print(df_emodnet.columns)
print(df_emodnet.shape)
# Out:
# Index(['time (UTC)', 'latitude (degrees_north)', 'longitude (degrees_east)',
#        'depth (m)', 'PHPH (1)'],
#       dtype='object')
# (1971, 5)

# %% [markdown]
# ## Plot

# %%
df_emodnet['time (UTC)'] = pd.to_datetime(df_emodnet['time (UTC)'])
plt.figure(figsize=(12,6))
ax = plt.axes()
df_emodnet.plot(x='time (UTC)', y='PHPH (1)',ax=ax, 
                linestyle='None', marker='o',grid='on', legend=True)
plt.show()

# %% [markdown]
# # Other ERDDAP servers (IFREMER...)

# %%
i = ERDDAP(server='IFREMER',protocol='tabledap')
i.response = 'csv'

i.dataset_id="ArgoFloats-synthetic-BGC"
# List of variables
info_url = i.get_info_url(response='csv')
info = pd.read_csv(info_url)
print(" ".join(info.loc[info["Row Type"] == "variable","Variable Name"]))
print(i.get_var_by_attr(
    i.dataset_id, standard_name=varstandname))
print(i.get_var_by_attr(i.dataset_id, axis=lambda v: v in ["X", "Y", "Z", "T"]))

print()

i.constraints= {
    "latitude<=": latmax,
    "latitude>=": latmin,
    "longitude>=": lonmin,
    "longitude<=": lonmax,
    "time>=": datemin,
    "time<=": datemax,
    "ph_in_situ_total_qc=":"1",
    "pres<=":10.,
#    "platform_number":
}


i.variables= ['time','latitude','longitude', 'ph_in_situ_total']

df_argo = i.to_pandas()
print(df_argo.columns)
print(df_argo.shape)
# Out:
# positioning_system wmo_inst_type platform_type parameter_data_mode data_centre format_version handbook_version data_type time time_qc time_location latitude longitude position_qc platform_number cycle_number direction config_mission_number cndc cndc_qc cndc_dpres cndc_adjusted cndc_adjusted_qc cndc_adjusted_error pres pres_qc pres_dpres pres_adjusted pres_adjusted_qc pres_adjusted_error psal psal_qc psal_dpres psal_adjusted psal_adjusted_qc psal_adjusted_error temp temp_qc temp_dpres temp_adjusted temp_adjusted_qc temp_adjusted_error doxy doxy_qc doxy_dpres doxy_adjusted doxy_adjusted_qc doxy_adjusted_error temp_doxy temp_doxy_qc temp_doxy_dpres temp_doxy_adjusted temp_doxy_adjusted_qc temp_doxy_adjusted_error temp_voltage_doxy temp_voltage_doxy_qc temp_voltage_doxy_dpres temp_voltage_doxy_adjusted temp_voltage_doxy_adjusted_qc temp_voltage_doxy_adjusted_error voltage_doxy voltage_doxy_qc voltage_doxy_dpres voltage_doxy_adjusted voltage_doxy_adjusted_qc voltage_doxy_adjusted_error frequency_doxy frequency_doxy_qc frequency_doxy_dpres frequency_doxy_adjusted frequency_doxy_adjusted_qc frequency_doxy_adjusted_error count_doxy count_doxy_qc count_doxy_dpres count_doxy_adjusted count_doxy_adjusted_qc count_doxy_adjusted_error bphase_doxy bphase_doxy_qc bphase_doxy_dpres bphase_doxy_adjusted bphase_doxy_adjusted_qc bphase_doxy_adjusted_error dphase_doxy dphase_doxy_qc dphase_doxy_dpres dphase_doxy_adjusted dphase_doxy_adjusted_qc dphase_doxy_adjusted_error tphase_doxy tphase_doxy_qc tphase_doxy_dpres tphase_doxy_adjusted tphase_doxy_adjusted_qc tphase_doxy_adjusted_error c1phase_doxy c1phase_doxy_qc c1phase_doxy_dpres c1phase_doxy_adjusted c1phase_doxy_adjusted_qc c1phase_doxy_adjusted_error c2phase_doxy c2phase_doxy_qc c2phase_doxy_dpres c2phase_doxy_adjusted c2phase_doxy_adjusted_qc c2phase_doxy_adjusted_error molar_doxy molar_doxy_qc molar_doxy_dpres molar_doxy_adjusted molar_doxy_adjusted_qc molar_doxy_adjusted_error phase_delay_doxy phase_delay_doxy_qc phase_delay_doxy_dpres phase_delay_doxy_adjusted phase_delay_doxy_adjusted_qc phase_delay_doxy_adjusted_error mlpl_doxy mlpl_doxy_qc mlpl_doxy_dpres mlpl_doxy_adjusted mlpl_doxy_adjusted_qc mlpl_doxy_adjusted_error nb_sample nb_sample_qc nb_sample_dpres nb_sample_adjusted nb_sample_adjusted_qc nb_sample_adjusted_error rphase_doxy rphase_doxy_qc rphase_doxy_dpres rphase_doxy_adjusted rphase_doxy_adjusted_qc rphase_doxy_adjusted_error temp_count_doxy temp_count_doxy_qc temp_count_doxy_dpres temp_count_doxy_adjusted temp_count_doxy_adjusted_qc temp_count_doxy_adjusted_error led_flashing_count_doxy led_flashing_count_doxy_qc led_flashing_count_doxy_dpres led_flashing_count_doxy_adjusted led_flashing_count_doxy_adjusted_qc led_flashing_count_doxy_adjusted_error ppox_doxy ppox_doxy_qc ppox_doxy_dpres ppox_doxy_adjusted ppox_doxy_adjusted_qc ppox_doxy_adjusted_error beta_backscattering beta_backscattering_qc beta_backscattering_dpres beta_backscattering_adjusted beta_backscattering_adjusted_qc beta_backscattering_adjusted_error beta_backscattering470 beta_backscattering470_qc beta_backscattering470_dpres beta_backscattering470_adjusted beta_backscattering470_adjusted_qc beta_backscattering470_adjusted_error beta_backscattering532 beta_backscattering532_qc beta_backscattering532_dpres beta_backscattering532_adjusted beta_backscattering532_adjusted_qc beta_backscattering532_adjusted_error beta_backscattering700 beta_backscattering700_qc beta_backscattering700_dpres beta_backscattering700_adjusted beta_backscattering700_adjusted_qc beta_backscattering700_adjusted_error fluorescence_chla fluorescence_chla_qc fluorescence_chla_dpres fluorescence_chla_adjusted fluorescence_chla_adjusted_qc fluorescence_chla_adjusted_error temp_cpu_chla temp_cpu_chla_qc temp_cpu_chla_dpres temp_cpu_chla_adjusted temp_cpu_chla_adjusted_qc temp_cpu_chla_adjusted_error fluorescence_cdom fluorescence_cdom_qc fluorescence_cdom_dpres fluorescence_cdom_adjusted fluorescence_cdom_adjusted_qc fluorescence_cdom_adjuste ...
# []
# ['pres', 'time', 'pres_adjusted', 'longitude', 'latitude']
#
# Index(['time (UTC)', 'latitude (degrees_north)', 'longitude (degrees_east)',
#        'ph_in_situ_total (dimensionless)'],
#       dtype='object')
# (708, 4)

# %%
df_argo['time (UTC)'] = pd.to_datetime(df_argo['time (UTC)'])

plt.figure(figsize=(12,6))
ax = plt.axes()
df_emodnet.plot(x='time (UTC)', y='PHPH (1)',ax=ax, 
                linestyle='None', marker='o',grid='on', markersize=1, label="EMODnet", legend=True)
df_argo.plot(x='time (UTC)', y='ph_in_situ_total (dimensionless)',ax=ax, 
                linestyle='None', marker='o',grid='on', markersize=0.5, label="Argo")
plt.show()

# %% [markdown]
# # Scatter plot in map

# %%
proj=ccrs.cartopy.crs.Miller()
plt.figure(dpi=150)
ax = plt.axes(projection=proj)
ax.set_extent([lonmin-10, lonmax+10, latmax+5, latmin-5])
ax.stock_img()
ax.coastlines()
sc=ax.scatter(df_emodnet['longitude (degrees_east)'],df_emodnet['latitude (degrees_north)'],
              c='blue',s=0.2, label= "EMODnet",
             transform=ccrs.PlateCarree())
sc=ax.scatter(df_argo['longitude (degrees_east)'],df_argo['latitude (degrees_north)'],
              c='orange',s=0.2, label="Argo",
             transform=ccrs.PlateCarree())
ax.legend()
plt.show()

# %%
proj=ccrs.cartopy.crs.Miller()
plt.figure(dpi=150)
ax = plt.axes(projection=proj)
ax.set_extent([lonmin-10, lonmax+10, latmax+5, latmin-5])
ax.stock_img()
ax.coastlines()
sc=ax.scatter(df_emodnet['longitude (degrees_east)'],df_emodnet['latitude (degrees_north)'],
              c=df_emodnet['PHPH (1)'],s=0.2,
             transform=ccrs.PlateCarree())
sc=ax.scatter(df_argo['longitude (degrees_east)'],df_argo['latitude (degrees_north)'],
              c=df_argo['ph_in_situ_total (dimensionless)'],s=0.2,
             transform=ccrs.PlateCarree())
plt.colorbar(sc)
plt.show()

# %% [markdown]
# ## Bonus track. Griddap data background (temperature climatology)

# %%
g = ERDDAP(
  server='https://jeodpp.jrc.ec.europa.eu/services/erddap',
  protocol='griddap',
)
g.response = 'csv'
g.dataset_id = 'GLODAPv2_2016b_CMEMS'
g.variables = ['pHtsinsitutp']
df_glodapgrid = g.to_pandas()

surfg=df_glodapgrid.loc[df_glodapgrid['depth_surface (count)'] == 1,:]
lat=surfg['latitude (degrees_north)'].unique()
lon=surfg['longitude (degrees_east)'].unique()
phc=(surfg['pHtsinsitutp']).values.reshape(180,360)

proj=ccrs.cartopy.crs.Miller()
plt.figure(dpi=150)
ax = plt.axes(projection=proj)
ax.set_extent([lonmin-10, lonmax+10, latmax+5, latmin-5])
ax.stock_img()
ax.coastlines()
sc=ax.contourf(lon,lat,phc,transform=ccrs.PlateCarree())
sc=ax.scatter(df_emodnet['longitude (degrees_east)'],df_emodnet['latitude (degrees_north)'],
              c=df_emodnet['PHPH (1)'],s=1,
             transform=ccrs.PlateCarree())
sc=ax.scatter(df_argo['longitude (degrees_east)'],df_argo['latitude (degrees_north)'],
              c=df_argo['ph_in_situ_total (dimensionless)'],s=1,
             transform=ccrs.PlateCarree())
plt.colorbar(sc)
